# %% [markdown]
# <a href="https://colab.research.google.com/github/BhagyaSri-1806/DataAnalyst/blob/main/Business_Understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Bakery.csv')

# %%
data
# Out:
#        TransactionNo          Items             DateTime    Daypart  DayType
# 0                  1          Bread  2016-10-30 09:58:11    Morning  Weekend
# 1                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 2                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 3                  3  Hot chocolate  2016-10-30 10:07:57    Morning  Weekend
# 4                  3            Jam  2016-10-30 10:07:57    Morning  Weekend
# ...              ...            ...                  ...        ...      ...
# 20502           9682         Coffee  2017-09-04 14:32:58  Afternoon  Weekend
# 20503           9682            Tea  2017-09-04 14:32:58  Afternoon  Weekend
# 20504           9683         Coffee  2017-09-04 14:57:06  Afternoon  Weekend
# 20505           9683         Pastry  2017-09-04 14:57:06  Afternoon  Weekend
# 20506           9684      Smoothies  2017-09-04 15:04:24  Afternoon  Weekend
#
# [20507 rows x 5 columns]

# %% [markdown]
# # **1. Business Problem**
#
# # -->The bakery wants to increase sales and optimize inventory. Currently, they face challenges in:
#
# # -->Understanding peak selling times (e.g., morning vs. afternoon).
# #--> Identifying best-selling and least-selling items to improve stock management.
# # -->Predicting demand to reduce waste and avoid stockouts.

# %% [markdown]
# # **2. Business Objective**
# # The goal is to analyze customer purchasing patterns to improve business operations:
#
# # -->Increase sales by offering promotions during low-sales periods.
#
# # -->Introduce new products based on customer preferences.

# %% [markdown]
# # **3. Business Constraints**
# # -->Some sales might not be recorded correctly.
# # -->If the time of purchase is wrong, we may misinterpret peak hours.
# # -->"Choco Cake" and "Chocolate Cake" might be counted as different

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'data' DataFrame is already loaded as in the previous example

# Calculate item frequencies
item_counts = data['Items'].value_counts()

# Get the top 10 items
top_10_items = item_counts.head(10)

# Create a bar chart
plt.figure(figsize=(10, 6))
top_10_items.plot(kind='bar')
plt.title('Top 10 Best-Selling Items')
plt.xlabel('Items')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_10_items, labels=top_10_items.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 10 Best-Selling Items (Percentage)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# prompt: 10 low items

import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/Bakery.csv')

# Calculate item frequencies
item_counts = data['Items'].value_counts()

# Get the 10 least sold items
bottom_10_items = item_counts.tail(10)

# Create a bar chart for the 10 least sold items
plt.figure(figsize=(10, 6))
bottom_10_items.plot(kind='bar')
plt.title('10 Least-Selling Items')
plt.xlabel('Items')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Create a pie chart for the 10 least sold items
plt.figure(figsize=(8, 8))
plt.pie(bottom_10_items, labels=bottom_10_items.index, autopct='%1.1f%%', startangle=90)
plt.title('10 Least-Selling Items (Percentage)')
plt.axis('equal')
plt.show()

# %%
# prompt: confusion matrix with item names for the above dataset

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Assuming 'data' DataFrame is already loaded and preprocessed
# Replace with your actual data and target variable
# Example:
# data = pd.read_csv('/content/Bakery.csv')
# true_labels = data['actual_category'] # Replace 'actual_category' with the correct column name
# predicted_labels = data['predicted_category'] # Replace 'predicted_category' with the correct column name


# Example data (replace with your actual data)
true_labels = ['A', 'A', 'B', 'B', 'A', 'C', 'C', 'A', 'B', 'C']
predicted_labels = ['A', 'B', 'A', 'B', 'A', 'C', 'A', 'A', 'B', 'C']

# Create the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Create a DataFrame from the confusion matrix
cm_df = pd.DataFrame(cm, index = ['A', 'B', 'C'], columns = ['A', 'B', 'C'])  # Replace with your actual item names

# Plot the confusion matrix with item names as labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
